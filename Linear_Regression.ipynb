# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/My Drive/ML/Linear_Regression_Data/Data.csv'

# %%
# Load the data
data = pd.read_csv(file_path)
data.head()
data.head(data.shape[0])
# Out:
#       X           y
# 0    71  481.934555
# 1    34  196.197633
# 2    91  425.595659
# 3    80  393.329957
# 4    40  253.549823
# ..   ..         ...
# 995  59  294.730131
# 996  60  351.919438
# 997  30  175.271205
# 998  42  275.473645
# 999  20   71.592884
#
# [1000 rows x 2 columns]

# %%
X = data['X'].values  # Independent variable
y = data['y'].values  # Dependent variable

# %%
# Scatter plot of the data
plt.scatter(X, y)
plt.xlabel('X')
plt.ylabel('y')
plt.title('Scatter Plot of the Data')
plt.show()

# %%
# Initialize parameters
w0 = 300
w1 = 10
learning_rate = 0.0001
epochs = 10  # Number of iterations for gradient descent

n = float(len(X))  # Number of elements in X

# Perform Gradient Descent
for i in range(epochs):
    y_pred = w0 + w1 * X  # Predicted value of y
    D_w0 = (2/n) * sum(y_pred - y)  # Derivative w.r.t w0
    D_w1 = (2/n) * sum(X * (y_pred - y))  # Derivative w.r.t w1

    w0 = w0 - learning_rate * D_w0  # Update w0
    w1 = w1 - learning_rate * D_w1  # Update w1

    print(f"Epoch {i+1}: w0 = {w0}, w1 = {w1}")
# Out:
# Epoch 1: w0 = 299.88165234561177, w1 = 2.5854496137078558
# Epoch 2: w0 = 299.8495106457144, w1 = 0.9710122887213155
# Epoch 3: w0 = 299.8361406249603, w1 = 0.6195602762831425
# Epoch 4: w0 = 299.8268583455317, w1 = 0.5431256421525923
# Epoch 5: w0 = 299.81846635288537, w1 = 0.526576546730256
# Epoch 6: w0 = 299.8102683953933, w1 = 0.5230676352173071
# Epoch 7: w0 = 299.8021128629748, w1 = 0.5223982452185258
# Epoch 8: w0 = 299.7939667422505, w1 = 0.5223471636863104
# Epoch 9: w0 = 299.78582284449146, w1 = 0.5224307173834616
# Epoch 10: w0 = 299.7776796043339, w1 = 0.5225435855707045

# %%
predictions = w0 + w1 * X
predictions
# Out:
# array([336.87827418, 317.54416151, 347.32914589, 341.58116645,
#        320.67942303, 348.89677665, 348.89677665, 322.24705378,
#        311.27363849, 321.20196661, 337.40081777, 310.7510949 ,
#        325.3823153 , 329.56266398, 310.7510949 , 343.14879721,
#        341.05862286, 320.67942303, 326.94994605, 349.41932023,
#        340.01353569, 321.20196661, 335.31064342, 340.53607928,
#        331.65283832, 341.05862286, 351.50949458, 317.54416151,
#        342.10371004, 342.10371004, 334.26555625, 342.10371004,
#        336.35573059, 338.44590494, 343.14879721, 311.27363849,
#        336.35573059, 313.36381283, 320.67942303, 347.85168948,
#        330.08520757, 319.11179227, 311.79618207, 341.05862286,
#        317.02161793, 314.4089    , 337.40081777, 310.7510949 ,
#        341.05862286, 346.80660231, 332.6979255 , 313.88635641,
#        334.26555625, 327.99503323, 350.4644074 , 328.51757681,
#        335.83318701, 311.79618207, 310.7510949 , 312.84126924,
# ...

# %%
# Plot the results
plt.scatter(X, y, label='Actual Data')
plt.plot(X, predictions, color='red', label='Fitted Line')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
plt.show()
